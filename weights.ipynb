# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
backpack = pd.read_csv('backpack.csv')

# %%
backpack.plot()

# %%
backpack.sort('weight', ascending=False, inplace=True)

# %%
backpack[:20]
# Out:
#     weight                             item  \
# 81  100.05                         backpack
# 83   73.10                           duffel
# 72   45.95                         backpack
# 76   37.95                             tent
# 45   35.45                     sleeping mat
# 84   31.40                     sleeping pad
# 34   29.65   msr stove with 2L aluminum pot
# 36   27.60                      down jacket
# 40   24.60                       down quilt
# 11   23.55                    canister fuel
# 37   20.90                     down blanket
# 71   20.80                         backpack
# 35   20.60                     sleeping bag
# 27   15.60           Sierra North guidebook
# 74   15.35                            pants
# 63   15.25                      rain jacket
# 28   12.30                  2L aluminum pot
# 62   12.15                     hiking pants
# 33   11.95   complete msr windpro stove kit
# 73   11.45                            shirt
#
# ...
