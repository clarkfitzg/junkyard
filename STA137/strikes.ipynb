# %%
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
strikes = pd.read_fwf('strikes.dat', header=None)
strikes.index = pd.date_range('1951-1-1', periods=len(strikes), freq='A')

# %%
# Add centered rolling mean
q = [2, 4, 5]
for qi in q:
    strikes['q' + str(qi)] = pd.rolling_mean(strikes.iloc[:, 0], window=2 * qi + 1, center=True)

# %%
strikes.head()
# Out:
#                0      q2           q4  q5
# 1951-12-31  4737     NaN          NaN NaN
# 1952-12-31  5117     NaN          NaN NaN
# 1953-12-31  5091  4546.6          NaN NaN
# 1954-12-31  3468  4364.2          NaN NaN
# 1955-12-31  4320  4075.4  4181.444444 NaN

# %%
strikes.shape
# Out:
# (30, 4)

# %%
strikes.plot()
plt.plot(pd.ewma(strikes.iloc[:, 1], halflife=2))

# %%
strikes[:, 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-3b00f3cf3f0a> in <module>()
# ----> 1 strikes[:, 0]
#
# /Users/clark/anaconda/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /Users/clark/anaconda/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /Users/clark/anaconda/lib/python3.4/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1064         """ return the cached item, item represents a label indexer """
#    1065         cache = self._item_cache
# -> 1066         res = cache.get(item)
#    1067         if res is None:
#    1068             values = self._data.get(item)
#
# TypeError: unhashable type: 'slice'
